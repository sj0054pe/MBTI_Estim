# %%
# %cd /content/drive/MyDrive/研究室/研究_M2/src
# Out:
# /content/drive/MyDrive/研究室/研究_M2/src

# %%
import datetime
from pytz import timezone

def Pull_Datetime():
    dates=datetime.datetime.now(timezone('Asia/Tokyo'))
    exept_microsec=dates.strftime("%Y-%m-%d-%H-%M")
    print('[Today : %s]' % str(exept_microsec))

    DATETIME=exept_microsec
    return DATETIME

DATETIME=Pull_Datetime()
# Out:
# [Today : 2021-08-24-00-36]

# %%
KEYWORDS_FileName= '2017'

# %%
import os
OUTPUT_PATH =  './Assets/Assets_Output/'
OUTPUT_DIR=OUTPUT_PATH+ "PersonalEstim_%s/" % DATETIME
OUTPUT_DIR_RESULTS=OUTPUT_PATH+ "PersonalEstim_%s/results/" % DATETIME

KEYWORDS_TypeMBTI = '2017-2018'

try:
  os.mkdir(OUTPUT_DIR)
except:
  print(OUTPUT_DIR, '    already exists')
  print()
try:
  os.mkdir(OUTPUT_DIR_RESULTS)
except:
  print(OUTPUT_DIR_RESULTS, '    the directory already exists')
  print()

# %%
import yaml
import os # For saving access tokens and for file management when creating and adding to the dataset
import requests # For sending GET requests from the API
import Twitter_API_Key

def Create_url_SearchTweets(keyword, start_date, end_date, max_results = 10):
    #Change to the endpoint you want to collect data from
    search_url = "https://api.twitter.com/2/tweets/search/all" 
    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
                    
    return (search_url, query_params)

# %%
def Connect_to_endpoint(url, params, next_token = None):
    #prepare params
    params['next_token'] = next_token   #params object received from create_url function
    #pull bearer token
    bearer_token = Twitter_API_Key.Auth_FullAchieve()
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    #request Twtitter
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
        
    return response.json()

# %%
import dateutil.parser
import pandas as pd

def Search_Tweets(keyword, start_time, end_time, max_results, next_token, KEYWORDS_FileName, count_index):
  url = Create_url_SearchTweets(keyword, start_time, end_time, max_results)
  print(url)
  json_SearchTweets= Connect_to_endpoint(url[0], url[1], next_token)
  # json_SearchTweets
  print(json_SearchTweets)
  list_EachData=json_SearchTweets['data']

  list_csv=[]
  list_csv.clear()
  list_header=['author_id', 'text', 'tweet_id', 'tweet_time', 'lang']
  for element in list_EachData:
    #print(element['text'])
    tweet_AuthorID=element['author_id']
    tweet_Texts=element['text']
    tweet_id = element['id']
    tweet_time = dateutil.parser.parse(element['created_at'])
    tweet_lang = element['lang']

    list_sub_row=[tweet_AuthorID, tweet_Texts, tweet_id, tweet_time, tweet_lang]
    list_csv.append(list_sub_row)

  df_SearchTweets=pd.DataFrame(list_csv, columns=list_header)
  df_SearchTweets.to_csv('%sUserList_%s.csv' % (OUTPUT_DIR_RESULTS, count_index))
  print('%sUserList_%s.csvを作成しました。'% (OUTPUT_DIR_RESULTS, count_index))

  return df_SearchTweets, tweet_time

# %%
import time

#Inputs for the request
keyword = "#16Personalities 16personalities.com lang:ja"
max_results = 500
start_time = "2017-01-01T00:00:00.000Z"
end_time='2017-12-31T23:59:59.000Z'
# start_time = "2018-12-31T00:00:00.000Z"
# end_time='2018-12-31T23:59:59.000Z'
df_2017to2018=None

for count_index in range(0, 10000):
  print(count_index)
  next_token = None
  df_SearchTweets, end_time=Search_Tweets(keyword, start_time, end_time, max_results, next_token, KEYWORDS_TypeMBTI, count_index)

  b=str(end_time).replace(' ', 'T')
  #print(b.split('+'))
  c=b.split('+')
  end_time=c[0] + '.000Z'
  #print(d)
  
  df_2017to2018=pd.concat([df_2017to2018, df_SearchTweets], axis=0)
  # except:
  #   print('passしました')
  #   pass

  #time.sleep(5)
  print(end_time)
  
df_2017to2018.to_csv('%sUserListFinal_%s.csv' % (OUTPUT_DIR_RESULTS, KEYWORDS_FileName))
#df_SearchTweets.to_csv('%sUserList_%s.csv' % (OUTPUT_DIR_RESULTS, KEYWORDS_FileName))
# Out:
# 0
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-12-31T23:59:59.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_0.csvを作成しました。
# 2017-12-19T16:28:07.000Z
# 1
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-12-19T16:28:07.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_1.csvを作成しました。
# 2017-12-14T04:34:56.000Z
# 2
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-12-14T04:34:56.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_2.csvを作成しました。
# 2017-12-05T17:41:44.000Z
# 3
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-12-05T17:41:44.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_3.csvを作成しました。
# 2017-11-27T05:21:19.000Z
# 4
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-11-27T05:21:19.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_4.csvを作成しました。
# 2017-11-23T17:29:45.000Z
# 5
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-11-23T17:29:45.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_5.csvを作成しました。
# 2017-11-14T07:54:20.000Z
# 6
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-11-14T07:54:20.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_6.csvを作成しました。
# 2017-11-03T14:20:04.000Z
# 7
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-11-03T14:20:04.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_7.csvを作成しました。
# 2017-10-25T04:21:59.000Z
# 8
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-10-25T04:21:59.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_8.csvを作成しました。
# 2017-10-16T14:27:59.000Z
# 9
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-10-16T14:27:59.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_9.csvを作成しました。
# 2017-09-28T10:58:51.000Z
# 10
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-09-28T10:58:51.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_10.csvを作成しました。
# 2017-09-10T09:06:49.000Z
# 11
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-09-10T09:06:49.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_11.csvを作成しました。
# 2017-08-29T22:23:59.000Z
# 12
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-08-29T22:23:59.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_12.csvを作成しました。
# 2017-08-10T07:15:19.000Z
# 13
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-08-10T07:15:19.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_13.csvを作成しました。
# 2017-07-20T23:01:01.000Z
# 14
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-07-20T23:01:01.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_14.csvを作成しました。
# 2017-07-09T10:07:02.000Z
# 15
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-07-09T10:07:02.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_15.csvを作成しました。
# 2017-06-27T14:56:35.000Z
# 16
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-06-27T14:56:35.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_16.csvを作成しました。
# 2017-06-20T07:46:42.000Z
# 17
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-06-20T07:46:42.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_17.csvを作成しました。
# 2017-06-11T04:27:27.000Z
# 18
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-06-11T04:27:27.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_18.csvを作成しました。
# 2017-05-27T22:55:52.000Z
# 19
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-05-27T22:55:52.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_19.csvを作成しました。
# 2017-05-20T08:24:49.000Z
# 20
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-05-20T08:24:49.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_20.csvを作成しました。
# 2017-05-14T02:16:36.000Z
# 21
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-05-14T02:16:36.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_21.csvを作成しました。
# 2017-05-05T13:11:35.000Z
# 22
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-05-05T13:11:35.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_22.csvを作成しました。
# 2017-04-26T10:30:03.000Z
# 23
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04-26T10:30:03.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_23.csvを作成しました。
# 2017-04-21T08:24:36.000Z
# 24
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04-21T08:24:36.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_24.csvを作成しました。
# 2017-04-19T16:39:10.000Z
# 25
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04-19T16:39:10.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_25.csvを作成しました。
# 2017-04-19T02:38:02.000Z
# 26
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04-19T02:38:02.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_26.csvを作成しました。
# 2017-04-17T15:31:57.000Z
# 27
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04-17T15:31:57.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_27.csvを作成しました。
# 2017-04-17T01:58:28.000Z
# 28
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04-17T01:58:28.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_28.csvを作成しました。
# 2017-04-16T10:28:20.000Z
# 29
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-04
000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_65.csvを作成しました。
# 2017-03-01T04:19:49.000Z
# 66
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-03-01T04:19:49.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_66.csvを作成しました。
# 2017-02-21T13:56:12.000Z
# 67
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-02-21T13:56:12.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_67.csvを作成しました。
# 2017-02-12T14:00:14.000Z
# 68
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-02-12T14:00:14.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_68.csvを作成しました。
# 2017-01-31T18:31:08.000Z
# 69
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-01-31T18:31:08.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_69.csvを作成しました。
# 2017-01-22T13:41:49.000Z
# 70
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-01-22T13:41:49.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_70.csvを作成しました。
# 2017-01-15T07:15:43.000Z
# 71
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-01-15T07:15:43.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_71.csvを作成しました。
# 2017-01-08T06:06:26.000Z
# 72
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-01-08T06:06:26.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserList_72.csvを作成しました。
# 2017-01-01T04:44:24.000Z
# 73
# ('https://api.twitter.com/2/tweets/search/all', {'query': '#16Personalities 16personalities.com lang:ja', 'start_time': '2017-01-01T00:00:00.000Z', 'end_time': '2017-01-01T04:44:24.000Z', 'max_results': 500, 'expansions': 'author_id,in_reply_to_user_id,geo.place_id', 'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source', 'user.fields': 'id,name,username,created_at,description,public_metrics,verified', 'place.fields': 'full_name,id,country,country_code,geo,name,place_type', 'next_token': {}})
# Endpoint Response Code: 200
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-54aafac312b8> in <module>()
#      13   print(count_index)
#      14   next_token = None
# ---> 15   df_SearchTweets, end_time=Search_Tweets(keyword, start_time, end_time, max_results, next_token, KEYWORDS_TypeMBTI, count_index)
#      16
#      17   b=str(end_time).replace(' ', 'T')
#
# <ipython-input-7-a3487a52856c> in Search_Tweets(keyword, start_time, end_time, max_results, next_token, KEYWORDS_FileName, count_index)
#       8   # json_SearchTweets
#       9   # print(json_SearchTweets)
# ---> 10   list_EachData=json_SearchTweets['data']
#      11
#      12   list_csv=[]
#
# KeyError: 'data'

# %%
df_SearchTweets
# Out:
#               author_id  ... lang
# 0    758875042994204673  ...   ja
# 1            2499059894  ...   ja
# 2             352949960  ...   ja
# 3            2956855579  ...   ja
# 4             622561432  ...   ja
# ..                  ...  ...  ...
# 462           879292549  ...   ja
# 463  781783504199614464  ...   ja
# 464           589077235  ...   ja
# 465          1017366481  ...   ja
# 466           407763079  ...   ja
#
# [467 rows x 5 columns]

# %%
df_2017to2018
# Out:
#               author_id  ... lang
# 0            1620241032  ...   ja
# 1    708171936782622720  ...   ja
# 2            4256765894  ...   ja
# 3    711443626774016000  ...   ja
# 4    711443626774016000  ...   ja
# ..                  ...  ...  ...
# 462           879292549  ...   ja
# 463  781783504199614464  ...   ja
# 464           589077235  ...   ja
# 465          1017366481  ...   ja
# 466           407763079  ...   ja
#
# [36254 rows x 5 columns]

# %%
df_2017to2018.to_csv('%sUserListFinal_%s.csv' % (OUTPUT_DIR_RESULTS, KEYWORDS_FileName))

# %%
print('%sUserListFinal_%s.csv' % (OUTPUT_DIR_RESULTS, KEYWORDS_FileName))
# Out:
# ./Assets/Assets_Output/PersonalEstim_2021-08-24-00-36/results/UserListFinal_2017.csv

# %%
list_AuthorID=df_2017to2018['author_id'].values.tolist()

# %%
list_AuthorID.sort()

# %%
print(list_AuthorID)
# Out:
