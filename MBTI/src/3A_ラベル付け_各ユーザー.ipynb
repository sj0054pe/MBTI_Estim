# %% [markdown]
# #<center>各ユーザーのラベル付け (ラベル=MBTItype) </center>

# %% [markdown]
# #0. 作業環境の準備

# %%
# %cd /content/drive/MyDrive/研究室/研究_M2/src
# Out:
# /content/drive/MyDrive/研究室/研究_M2/src

# %%
# !ls
# Out:
# よくわからない			       practice
# 02_elementary_Japanese_NLP.ipynb.json  __pycache__
# Assets				       Twitter_API_Key.py
# BERT⑤_distilと比較するbase	       Twitter_gathering_Authors.ipynb
# bert_finetuning_config_v1.json	       Twitter_gathering_Tweets.ipynb
# BERT⑥_Huggingface		       Twitter_Listening.ipynb
# config.py			       Untitled1.ipynb
# config.yaml			       データの前処理.ipynb
# FullAchieve_これならできそう.ipynb     形態素解析.ipynb
# FullAchieve_色々試行錯誤.ipynb

# %% [markdown]
# #1. データのロード

# %%
import pandas as pd
df_2017=pd.read_csv('/content/drive/MyDrive/研究室/研究_M2/src/Assets/Assets_Output/Tweet_Datasets/Tweet__MBTI_2017.csv', engine='python')

df_2017=df_2017[:][:] #df_2017=df_2017[:96][:]

# %% [markdown]
# #2. これから追加するカラムの追加

# %%
df_2017['MBTI_性格タイプ'] = None
df_2017['MBTI_Type'] = None
df_2017['notes'] = None
df_2017
# Out:
#        Unnamed: 0     author_id  ... MBTI_Type  notes
# 0           36301  4.077631e+08  ...      None   None
# 1           36300  1.017366e+09  ...      None   None
# 2           36299  5.890772e+08  ...      None   None
# 3           36298  7.817835e+17  ...      None   None
# 4           36297  8.792925e+08  ...      None   None
# ...           ...           ...  ...       ...    ...
# 36272           4  7.114440e+17  ...      None   None
# 36273           3  7.114440e+17  ...      None   None
# 36274           2  4.256766e+09  ...      None   None
# 36275           1  7.081719e+17  ...      None   None
# 36276           0  1.620241e+09  ...      None   None
#
# [36277 rows x 9 columns]

# %% [markdown]
# #3. 性格を宣言 (「私の性格タイプは...」) というツイートだけ抽出
#
# 性格を宣言するTweetの行で新しいdfを作成した。

# %%
df_2017_私の性格タイプ=df_2017[df_2017['text'].str.startswith('私の性格タイプは')]
df_2017_私の性格タイプ
# Out:
#        Unnamed: 0     author_id  ... MBTI_Type  notes
# 0           36301  4.077631e+08  ...      None   None
# 1           36300  1.017366e+09  ...      None   None
# 2           36299  5.890772e+08  ...      None   None
# 3           36298  7.817835e+17  ...      None   None
# 4           36297  8.792925e+08  ...      None   None
# ...           ...           ...  ...       ...    ...
# 36271           5  1.431154e+08  ...      None   None
# 36272           4  7.114440e+17  ...      None   None
# 36274           2  4.256766e+09  ...      None   None
# 36275           1  7.081719e+17  ...      None   None
# 36276           0  1.620241e+09  ...      None   None
#
# [32493 rows x 9 columns]

# %% [markdown]
# #4. MBTI性格 (日本語) を 抽出して、新しいカラムに追加
#
# 「MBTI_性格タイプ」のカラムに追加していく。

# %%
df_2017_私の性格タイプ['MBTI_性格タイプ']=df_2017_私の性格タイプ['text'].str.extract(r'私の性格タイプは\ \“(.*)\”\ です。', expand=True)
df_2017_性格タイプ=df_2017_私の性格タイプ

df_2017_性格タイプ
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0     author_id  ... MBTI_Type  notes
# 0           36301  4.077631e+08  ...      None   None
# 1           36300  1.017366e+09  ...      None   None
# 2           36299  5.890772e+08  ...      None   None
# 3           36298  7.817835e+17  ...      None   None
# 4           36297  8.792925e+08  ...      None   None
# ...           ...           ...  ...       ...    ...
# 36271           5  1.431154e+08  ...      None   None
# 36272           4  7.114440e+17  ...      None   None
# 36274           2  4.256766e+09  ...      None   None
# 36275           1  7.081719e+17  ...      None   None
# 36276           0  1.620241e+09  ...      None   None
#
# [32493 rows x 9 columns]

# %% [markdown]
# https://www.delftstack.com/ja/howto/python-pandas/how-to-create-dataframe-column-based-on-given-condition-in-pandas/

# %% [markdown]
# #5. MBTI性格 (日本語) を MBTI性格 (英語) に変換して、新しいカラムに追加
#
# 「MBTI_Type」のカラムに追加していく。

# %%
keys = ['建築家', '論理学者', '指揮官', '討論者', '提唱者', '仲介者', '主人公', '広報運動家', '管理者', '擁護者', '幹部', '領事官', '巨匠', '冒険家', '起業家', 'エンターテイナー']
values = ['INTJ', 'INTP', 'ENTJ', 'ENTP', 'INFJ', 'INFP', 'ENFJ', 'ENFP', 'ISTJ', 'ISFJ', 'ESTJ', 'ESFJ', 'ISTP', 'ISFP', 'ESTP', 'ESFP']

dic = {key: val for key, val in zip(keys, values)}

print(dic)

dict_MBTIType=dic
# Out:
# {'建築家': 'INTJ', '論理学者': 'INTP', '指揮官': 'ENTJ', '討論者': 'ENTP', '提唱者': 'INFJ', '仲介者': 'INFP', '主人公': 'ENFJ', '広報運動家': 'ENFP', '管理者': 'ISTJ', '擁護者': 'ISFJ', '幹部': 'ESTJ', '領事官': 'ESFJ', '巨匠': 'ISTP', '冒険家': 'ISFP', '起業家': 'ESTP', 'エンターテイナー': 'ESFP'}

# %%
df_2017_practice=df_2017_性格タイプ

def add_columns_by_conditions(df, Type_Japanese, Type_English):
  df['MBTI_Type'].where(df['MBTI_性格タイプ']!='%s' % Type_Japanese, '%s' % Type_English, inplace=True)

  return df

for element in dict_MBTIType:
  df_2017_practice=add_columns_by_conditions(df_2017_practice, element, dict_MBTIType[element])

#df_2017_性格タイプ['MBTI_Type'].where(df_2017_性格タイプ['MBTI_性格タイプ']!='建築家','INTJ', inplace=True)

df_2017_practice
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:9011: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cond, other, inplace, axis, level, errors=errors, try_cast=try_cast
#        Unnamed: 0     author_id  ... MBTI_Type  notes
# 0           36301  4.077631e+08  ...      ISFP   None
# 1           36300  1.017366e+09  ...      ISFJ   None
# 2           36299  5.890772e+08  ...      ESFP   None
# 3           36298  7.817835e+17  ...      INTJ   None
# 4           36297  8.792925e+08  ...      INTP   None
# ...           ...           ...  ...       ...    ...
# 36271           5  1.431154e+08  ...      ENFP   None
# 36272           4  7.114440e+17  ...      INFP   None
# 36274           2  4.256766e+09  ...      ENFP   None
# 36275           1  7.081719e+17  ...      INFP   None
# 36276           0  1.620241e+09  ...      INTJ   None
#
# [32493 rows x 9 columns]

# %% [markdown]
# #6. 結果を新しいcsvとして保存
#
# 「Tweet__MBTI_2017_V2.csv」として保存した。

# %%
df_2017_MBTI = df_2017_practice
df_2017_MBTI.to_csv('/content/drive/MyDrive/研究室/研究_M2/src/Assets/Assets_Output/Tweet_Datasets/Tweet__MBTI_2017_v2.csv')
